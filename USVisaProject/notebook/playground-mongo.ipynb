# %%
import pandas as pd

df = pd.read_csv('visa_data.csv')
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
data = df.to_dict(orient="records")
data[0]
# Out:
# {'case_id': 'EZYV01',
#  'continent': 'Asia',
#  'education_of_employee': 'High School',
#  'has_job_experience': 'N',
#  'requires_job_training': 'N',
#  'no_of_employees': 14513,
#  'yr_of_estab': 2007,
#  'region_of_employment': 'West',
#  'prevailing_wage': 592.2029,
#  'unit_of_wage': 'Hour',
#  'full_time_position': 'Y',
#  'case_status': 'Denied'}

# %%
len(data)
# Out:
# 25480

# %% [markdown]
# # Connect to MongoDB

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
db_name = "us-visa"
collection_name = "us-visa"
connection_string = 'mongodb+srv://gaurav98094:gaurav98094@cluster0.1vgsge7.mongodb.net/'

client = MongoClient(connection_string, server_api=ServerApi('1'))

# %%
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
database = client[db_name]
collection = database[collection_name]

# %%
recc = collection.insert_many(data)

# %%
recc
# Out:
# InsertManyResult([ObjectId('6689720c84c493cace8d85ff'), ObjectId('6689720c84c493cace8d8600'), ObjectId('6689720c84c493cace8d8601'), ObjectId('6689720c84c493cace8d8602'), ObjectId('6689720c84c493cace8d8603'), ObjectId('6689720c84c493cace8d8604'), ObjectId('6689720c84c493cace8d8605'), ObjectId('6689720c84c493cace8d8606'), ObjectId('6689720c84c493cace8d8607'), ObjectId('6689720c84c493cace8d8608'), ObjectId('6689720c84c493cace8d8609'), ObjectId('6689720c84c493cace8d860a'), ObjectId('6689720c84c493cace8d860b'), ObjectId('6689720c84c493cace8d860c'), ObjectId('6689720c84c493cace8d860d'), ObjectId('6689720c84c493cace8d860e'), ObjectId('6689720c84c493cace8d860f'), ObjectId('6689720c84c493cace8d8610'), ObjectId('6689720c84c493cace8d8611'), ObjectId('6689720c84c493cace8d8612'), ObjectId('6689720c84c493cace8d8613'), ObjectId('6689720c84c493cace8d8614'), ObjectId('6689720c84c493cace8d8615'), ObjectId('6689720c84c493cace8d8616'), ObjectId('6689720c84c493cace8d8617'), ObjectId('6689720c84c493cace8d
# ...

# %%
records = collection.find()
for rec in records:
    print(rec)
    break
# Out:
# {'_id': ObjectId('668818aa4529fcd72c7e6539'), 'case_id': 'EZYV01', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 14513, 'yr_of_estab': 2007, 'region_of_employment': 'West', 'prevailing_wage': 592.2029, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}

# %%
pd.DataFrame(list(collection.find())).head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  668818aa4529fcd72c7e6539  EZYV01      Asia           High School
# 1  668818aa4529fcd72c7e653a  EZYV02      Asia              Master's
# 2  668818aa4529fcd72c7e653b  EZYV03      Asia            Bachelor's
# 3  668818aa4529fcd72c7e653c  EZYV04      Asia            Bachelor's
# 4  668818aa4529fcd72c7e653d  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# ...
